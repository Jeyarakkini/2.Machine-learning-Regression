# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
dataset = pd.read_csv('insurance_pre.csv')
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'charges'], dtype='object')

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
print(dataset)
dataset[['sex_male','smoker_yes']]=dataset[['sex_male','smoker_yes']].astype(int)
print(dataset)
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# ...

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset[['charges']]

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
param_grid = {'criterion':['squared_error', 'absolute_error', 'friedman_mse','poisson'],'max_features': ['sqrt','log2'],'splitter':['best','random']} 
grid=GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose = 3,n_jobs=-1)
grid.fit(indep,dep)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'squared_error', 'max_features': 'log2', 'splitter': 'random'}:

# %%
grid.best_params_
# Out:
# {'criterion': 'squared_error', 'max_features': 'log2', 'splitter': 'random'}

# %%
grid.cv_results_
# Out:
# {'mean_fit_time': array([0.01214905, 0.01027465, 0.01009536, 0.0102572 , 0.02872005,
#         0.023557  , 0.03094006, 0.02624216, 0.01019859, 0.00955901,
#         0.00599961, 0.0111372 , 0.01215749, 0.01131711, 0.01473088,
#         0.01005716]),
#  'std_fit_time': array([3.95844958e-03, 4.28368911e-04, 9.31481586e-05, 2.24491085e-04,
#         7.91523616e-03, 4.30729892e-03, 6.43287839e-03, 4.98691824e-03,
#         1.53858291e-04, 5.64980779e-03, 6.95852086e-03, 6.55269405e-03,
#         1.29234945e-03, 5.51314231e-03, 4.55207685e-03, 8.52645641e-06]),
#  'mean_score_time': array([0.00618315, 0.00406694, 0.00809488, 0.00210643, 0.00403814,
#         0.00441122, 0.00604057, 0.0040853 , 0.0020761 , 0.00200081,
#         0.00533938, 0.00401273, 0.00202208, 0.00806589, 0.00402675,
#         0.00205965]),
#  'std_score_time': array([0.00480611, 0.00498149, 0.00404833, 0.00421286, 0.0049457 ,
#         0.00465036, 0.00493212, 0.00500457, 0.0041522 , 0.00400162,
# ...

# %%
r_score=grid.best_score_
r_score
# Out:
# 0.7049948026512493

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 23
# BMI: 21
# Children: 1
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[4296.2712]
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
