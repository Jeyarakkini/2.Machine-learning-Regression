# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
dataset = pd.read_csv('insurance_pre.csv')
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'charges'], dtype='object')

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
print(dataset)
dataset[['sex_male','smoker_yes']]=dataset[['sex_male','smoker_yes']].astype(int)
print(dataset)
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset[['charges']]

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
param_grid = {'kernel':['rbf','linear','poly','sigmoid'],'gamma':['scale','auto'],'C':[1,10,100]}
grid=GridSearchCV(SVR(), param_grid, refit = True, verbose = 3,n_jobs=-1)
grid.fit(indep,dep)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [1, 10, 100], 'gamma': ['scale', 'auto'],
#                          'kernel': ['rbf', 'linear', 'poly', 'sigmoid']},
#              verbose=3)

# %%
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}:

# %%
grid.best_params_
# Out:
# {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}

# %%
grid.cv_results_
# Out:
# {'mean_fit_time': array([0.13499632, 0.10935097, 0.10490737, 0.13656187, 0.12709136,
#         0.10006304, 0.10455093, 0.13878803, 0.12605648, 0.10276375,
#         0.10584221, 0.13614397, 0.12723055, 0.09900985, 0.10561233,
#         0.14355645, 0.13230081, 0.11401644, 0.11617317, 0.14171338,
#         0.13133454, 0.11280437, 0.12900681, 0.14189701]),
#  'std_fit_time': array([0.01863619, 0.01138501, 0.00706186, 0.00567362, 0.00494072,
#         0.00331906, 0.00493094, 0.00541365, 0.00505116, 0.00987401,
#         0.00533254, 0.00526874, 0.00500002, 0.00757315, 0.00477718,
#         0.0099646 , 0.00549294, 0.00107024, 0.01019543, 0.00010598,
#         0.00637492, 0.0040088 , 0.00986701, 0.00513661]),
#  'mean_score_time': array([0.06670561, 0.01609774, 0.01686888, 0.02423725, 0.0695673 ,
#         0.01608872, 0.01811581, 0.02615943, 0.06843529, 0.0183043 ,
#         0.01621227, 0.02255907, 0.07074604, 0.02048993, 0.01627216,
#         0.02416453, 0.0696465 , 0.01741433, 0.01825333, 0.02427349,
#         0.06644092, 0.02014127, 0.01960521, 0.02002559]),
#  'std_score_time': array([4.61781602e-03, 4.93329033e-03, 4.23537233e-03, 4.95206849e-03,
#         3.40504610e-03, 4.92370633e-03, 4.02680502e-03, 5.03829405e-03,
#         4.04989570e-03, 3.64136926e-03, 5.04095775e-03, 3.82170728e-03,
#         1.55647318e-04, 4.03395838e-04, 4.73446393e-03, 4.90104522e-03,
#         4.74907848e-03, 6.42080726e-03, 4.10908006e-03, 4.95556853e-03,
#         4.95110116e-03, 2.90943356e-05, 1.23065859e-03, 2.42975255e-04]),
#  'param_C': masked_array(data=[1, 1, 1, 1, 1, 1, 1, 1, 10, 10, 10, 10, 10, 10, 10, 10,
#                     100, 100, 100, 100, 100, 100, 100, 100],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value=999999),
#  'param_gamma': masked_array(data=['scale', 'scale', 'scale', 'scale', 'auto', 'auto',
#                     'auto', 'auto', 'scale', 'scale', 'scale', 'scale',
#                     'auto', 'auto', 'auto', 'auto', 'scale', 'scale',
#                     'scale', 'scale', 'auto', 'auto', 'auto', 'auto'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_kernel': masked_array(data=['rbf', 'linear', 'poly', 'sigmoid', 'rbf', 'linear',
#                     'poly', 'sigmoid', 'rbf', 'linear', 'poly', 'sigmoid',
#                     'rbf', 'linear', 'poly', 'sigmoid', 'rbf', 'linear',
#                     'poly', 'sigmoid', 'rbf', 'linear', 'poly', 'sigmoid'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'C': 1, 'gamma': 'scale', 'kernel': 'rbf'},
#   {'C': 1, 'gamma': 'scale', 'kernel': 'linear'},
#   {'C': 1, 'gamma': 'scale', 'kernel': 'poly'},
#   {'C': 1, 'gamma': 'scale', 'kernel': 'sigmoid'},
#   {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'},
#   {'C': 1, 'gamma': 'auto', 'kernel': 'linear'},
#   {'C': 1, 'gamma': 'auto', 'kernel': 'poly'},
#   {'C': 1, 'gamma': 'auto', 'kernel': 'sigmoid'},
#   {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'},
#   {'C': 10, 'gamma': 'scale', 'kernel': 'linear'},
#   {'C': 10, 'gamma': 'scale', 'kernel': 'poly'},
#   {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'},
#   {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'},
#   {'C': 10, 'gamma': 'auto', 'kernel': 'linear'},
#   {'C': 10, 'gamma': 'auto', 'kernel': 'poly'},
#   {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'},
#   {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'},
#   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'},
#   {'C': 100, 'gamma': 'scale', 'kernel': 'poly'},
#   {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'},
#   {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'},
#   {'C': 100, 'gamma': 'auto', 'kernel': 'linear'},
#   {'C': 100, 'gamma': 'auto', 'kernel': 'poly'},
#   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}],
#  'split0_test_score': array([-0.10898461, -0.02562897, -0.09934759, -0.10060515, -0.10897405,
#         -0.02562897, -0.09956081, -0.10065169, -0.05051686,  0.48787341,
#          0.03904118,  0.02971638, -0.0504021 ,  0.48787341,  0.03722664,
#          0.02930083,  0.36006814,  0.64146403,  0.65401107,  0.5273669 ,
#          0.36072432,  0.64146403,  0.65066872,  0.53145936]),
#  'split1_test_score': array([-0.1062592 , -0.01163029, -0.0961808 , -0.09479033, -0.1062798 ,
#         -0.01163029, -0.09583715, -0.09470461, -0.04509649,  0.47234116,
#          0.04011056,  0.04276993, -0.04527595,  0.47234116,  0.04288373,
#          0.0433786 ,  0.34815795,  0.60199395,  0.61297563,  0.49075403,
#          0.34720611,  0.60199395,  0.61683607,  0.49218021]),
#  'split2_test_score': array([-0.07505998,  0.00786576, -0.06648597, -0.06637099, -0.07507516,
#          0.00786576, -0.06622158, -0.06631029, -0.01660105,  0.48510241,
#          0.06336243,  0.05985231, -0.01673688,  0.48510241,  0.06567166,
#          0.06040215,  0.36231223,  0.62733901,  0.6367083 ,  0.52006438,
#          0.3614374 ,  0.62733901,  0.64213654,  0.51872618]),
#  'split3_test_score': array([-0.099683  , -0.01433679, -0.09109924, -0.09102836, -0.09967594,
#         -0.01433679, -0.09122629, -0.09105785, -0.04141474,  0.47583469,
#          0.04250578,  0.04091753, -0.04134517,  0.47583469,  0.04140573,
#          0.0406886 ,  0.34325538,  0.62887727,  0.61757329,  0.51121541,
#          0.34368203,  0.62887727,  0.61546248,  0.51164648]),
#  'split4_test_score': array([-0.10079155, -0.02738067, -0.09225161, -0.09377393, -0.10077757,
#         -0.02738067, -0.09242559, -0.0938133 , -0.0486001 ,  0.44769233,
#          0.03659431,  0.01823383, -0.04849124,  0.44769233,  0.03439333,
#          0.01782399,  0.33252066,  0.59623384,  0.60887701,  0.48549416,
#          0.3332901 ,  0.59623384,  0.60649669,  0.48650315]),
#  'mean_test_score': array([-0.09815567, -0.01422219, -0.08907304, -0.08931375, -0.09815651,
#         -0.01422219, -0.08905428, -0.08930755, -0.04044585,  0.4737688 ,
#          0.04432285,  0.038298  , -0.04045027,  0.4737688 ,  0.04431622,
#          0.03831883,  0.34926287,  0.61918162,  0.62602906,  0.50697898,
#          0.34926799,  0.61918162,  0.6263201 ,  0.50810308]),
#  'std_test_score': array([0.01204678, 0.01263225, 0.01166594, 0.01188858, 0.01204105,
#         0.01263225, 0.01177973, 0.01191685, 0.01232119, 0.01423853,
#         0.00970749, 0.0139116 , 0.01224834, 0.01423853, 0.01109328,
#         0.01428463, 0.01099684, 0.01719925, 0.01693   , 0.0163076 ,
#         0.01067791, 0.01719925, 0.01699304, 0.01667943]),
#  'rank_test_score': array([23, 15, 20, 22, 24, 15, 19, 21, 17,  7, 11, 14, 18,  7, 12, 13, 10,
#          3,  2,  6,  9,  3,  1,  5])}

# %%
r_score=grid.best_score_
r_score
# Out:
# 0.6263201010542734

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 38
# BMI: 22
# Children: 1
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[41015190.07221949]
