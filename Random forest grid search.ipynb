# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
dataset = pd.read_csv('insurance_pre.csv')
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'charges'], dtype='object')

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
print(dataset)
dataset[['sex_male','smoker_yes']]=dataset[['sex_male','smoker_yes']].astype(int)
print(dataset)
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset[['charges']]

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
param_grid = {'criterion':['squared_error', 'absolute_error', 'friedman_mse','poisson'],'max_features': ['sqrt','log2'],'n_estimators':[10,100]} 
grid=GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose = 3,n_jobs=-1)
grid.fit(indep,dep)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
grid.best_params_
# Out:
# {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'n_estimators': 100}

# %%
grid.cv_results_
# Out:
# {'mean_fit_time': array([0.06852336, 0.45148954, 0.05545053, 0.44285111, 0.15323358,
#         1.41483307, 0.14651036, 1.44506083, 0.04601355, 0.44790215,
#         0.05657148, 0.44740157, 0.08337183, 0.72207398, 0.08061004,
#         0.6359015 ]),
#  'std_fit_time': array([0.00462039, 0.01167179, 0.00419729, 0.00691714, 0.00770484,
#         0.02466516, 0.00504435, 0.02247371, 0.00419219, 0.0047311 ,
#         0.00470171, 0.00853711, 0.00699797, 0.00481743, 0.00637301,
#         0.07068329]),
#  'mean_score_time': array([0.00485191, 0.02013931, 0.0044179 , 0.0186677 , 0.00805674,
#         0.0218513 , 0.0040236 , 0.01810985, 0.00402493, 0.01813064,
#         0.00617599, 0.01991782, 0.00734997, 0.0162353 , 0.00407639,
#         0.01408677]),
#  'std_score_time': array([0.00607844, 0.0063778 , 0.00390285, 0.00287843, 0.00402837,
#         0.00681734, 0.00492789, 0.00402406, 0.00492952, 0.00402834,
#         0.00475784, 0.00548368, 0.00392896, 0.00504296, 0.0049931 ,
#         0.00493403]),
#  'param_criterion': masked_array(data=['squared_error', 'squared_error', 'squared_error',
#                     'squared_error', 'absolute_error', 'absolute_error',
#                     'absolute_error', 'absolute_error', 'friedman_mse',
#                     'friedman_mse', 'friedman_mse', 'friedman_mse',
#                     'poisson', 'poisson', 'poisson', 'poisson'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_features': masked_array(data=['sqrt', 'sqrt', 'log2', 'log2', 'sqrt', 'sqrt', 'log2',
#                     'log2', 'sqrt', 'sqrt', 'log2', 'log2', 'sqrt', 'sqrt',
#                     'log2', 'log2'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_n_estimators': masked_array(data=[10, 100, 10, 100, 10, 100, 10, 100, 10, 100, 10, 100,
#                     10, 100, 10, 100],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value=999999),
#  'params': [{'criterion': 'squared_error',
#    'max_features': 'sqrt',
#    'n_estimators': 10},
#   {'criterion': 'squared_error', 'max_features': 'sqrt', 'n_estimators': 100},
#   {'criterion': 'squared_error', 'max_features': 'log2', 'n_estimators': 10},
#   {'criterion': 'squared_error', 'max_features': 'log2', 'n_estimators': 100},
#   {'criterion': 'absolute_error', 'max_features': 'sqrt', 'n_estimators': 10},
#   {'criterion': 'absolute_error', 'max_features': 'sqrt', 'n_estimators': 100},
#   {'criterion': 'absolute_error', 'max_features': 'log2', 'n_estimators': 10},
#   {'criterion': 'absolute_error', 'max_features': 'log2', 'n_estimators': 100},
#   {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'n_estimators': 10},
#   {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'n_estimators': 100},
#   {'criterion': 'friedman_mse', 'max_features': 'log2', 'n_estimators': 10},
#   {'criterion': 'friedman_mse', 'max_features': 'log2', 'n_estimators': 100},
#   {'criterion': 'poisson', 'max_features': 'sqrt', 'n_estimators': 10},
#   {'criterion': 'poisson', 'max_features': 'sqrt', 'n_estimators': 100},
#   {'criterion': 'poisson', 'max_features': 'log2', 'n_estimators': 10},
#   {'criterion': 'poisson', 'max_features': 'log2', 'n_estimators': 100}],
#  'split0_test_score': array([0.85050378, 0.85799125, 0.84741643, 0.85587771, 0.85476133,
#         0.85621831, 0.81826355, 0.85324776, 0.82845565, 0.85905074,
#         0.84453107, 0.85604105, 0.84522087, 0.86067226, 0.84007114,
#         0.85703346]),
#  'split1_test_score': array([0.76777532, 0.77684595, 0.76602281, 0.77676553, 0.76572228,
#         0.77659647, 0.75921266, 0.7766011 , 0.75957747, 0.77869665,
#         0.77644689, 0.78088132, 0.7565412 , 0.77354484, 0.76022552,
#         0.77810354]),
#  'split2_test_score': array([0.84111521, 0.85885082, 0.83654007, 0.86166995, 0.84707426,
#         0.85297714, 0.83690554, 0.85889469, 0.84087953, 0.86359159,
#         0.83338684, 0.85801443, 0.85611241, 0.85978253, 0.84508989,
#         0.86212046]),
#  'split3_test_score': array([0.80398769, 0.82983369, 0.82265011, 0.82615471, 0.80568419,
#         0.82896994, 0.81877789, 0.82556791, 0.80638809, 0.82682431,
#         0.81517832, 0.82565038, 0.81503397, 0.82924121, 0.82365353,
#         0.82594305]),
#  'split4_test_score': array([0.82587733, 0.84053634, 0.82944758, 0.84167475, 0.83228311,
#         0.84210088, 0.83309048, 0.84058639, 0.83067283, 0.84199661,
#         0.8185368 , 0.8394094 , 0.83519597, 0.84363989, 0.82716781,
#         0.83947128]),
#  'mean_test_score': array([0.81785187, 0.83281161, 0.8204154 , 0.83242853, 0.82110504,
#         0.83137255, 0.81325003, 0.83097957, 0.81319471, 0.83403198,
#         0.81761598, 0.83199932, 0.82162088, 0.83337615, 0.81924158,
#         0.83253436]),
#  'std_test_score': array([0.02956895, 0.03004247, 0.02840489, 0.03042416, 0.03236402,
#         0.02900124, 0.02803197, 0.02950838, 0.02907222, 0.03058462,
#         0.02312932, 0.02815336, 0.03524106, 0.03207679, 0.03055222,
#         0.03009925]),
#  'rank_test_score': array([13,  3, 11,  5, 10,  7, 15,  8, 16,  1, 14,  6,  9,  2, 12,  4])}

# %%
r_score=grid.best_score_
r_score
# Out:
# 0.8340319786581958

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 34
# BMI: 23
# Children: 1
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[8810.2892636]
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
